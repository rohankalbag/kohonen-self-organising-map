# %%
from kohonen import kohonen
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
img = Image.open('initimg.png').convert('RGB')
img = img.resize((100, 100))
img_arr = np.asarray(img)
kohonen_som = kohonen(2, 2, 0.1, 3)
kohonen_som.fit(img_arr)
plt.imshow(kohonen_som.kohonen_map/255, interpolation='nearest')
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:01<00:00, 72.02it/s]

# %%
img = Image.open('initimg.png').convert('RGB')
img = img.resize((100, 100))
img_arr = np.asarray(img)
kohonen_som = kohonen(10, 10, 0.1, 2)
kohonen_som.fit(img_arr)
plt.imshow(kohonen_som.kohonen_map/255, interpolation='nearest')
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:26<00:00,  3.83it/s]

# %%
img = Image.open('initimg.png').convert('RGB')
img = img.resize((100, 100))
img_arr = np.asarray(img)
kohonen_som = kohonen(10, 10, 0.1, 2)
kohonen_som.fit(img_arr)
plt.imshow(kohonen_som.kohonen_map/255, interpolation='nearest')
plt.show()
# Out:
# ...
# 100%|██████████| 100/100 [00:26<00:00,  3.74it/s]
