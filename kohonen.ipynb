# %%
from kohonen import kohonen

# %%
img = Image.open('initimg.png').convert('RGB')
img = img.resize((100, 100))
img_arr = np.asarray(img)
kohonen_som = kohonen(10, 10, 0.1, 5)
kohonen_som.fit(img_arr)
# Out:
# 100%|██████████| 100/100 [00:27<00:00,  3.61it/s]
# 100%|██████████| 100/100 [00:27<00:00,  3.64it/s]
# 100%|██████████| 100/100 [00:27<00:00,  3.66it/s]
# 100%|██████████| 100/100 [00:26<00:00,  3.71it/s]
# 100%|██████████| 100/100 [00:27<00:00,  3.66it/s]

# %%
plt.imshow(kohonen_som.kohonen_map/255, interpolation='nearest')
plt.show()

# %%
img = Image.open('initimg.png').convert('RGB')
img = img.resize((100, 100))
img_arr = np.asarray(img)
kohonen_som = kohonen(10, 10, 0.1, 1)
kohonen_som.fit(img_arr)
# Out:
# 100%|██████████| 100/100 [00:27<00:00,  3.64it/s]

# %%
plt.imshow(kohonen_som.kohonen_map/255, interpolation='nearest')
plt.show()

# %%
img = Image.open('initimg.png').convert('RGB')
img = img.resize((100, 100))
img_arr = np.asarray(img)
kohonen_som = kohonen(2, 2, 0.1, 12)
kohonen_som.fit(img_arr)
plt.imshow(kohonen_som.kohonen_map/255, interpolation='nearest')
plt.show()
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 70.69it/s]
# 100%|██████████| 100/100 [00:01<00:00, 75.05it/s]
# 100%|██████████| 100/100 [00:01<00:00, 71.57it/s]
# 100%|██████████| 100/100 [00:01<00:00, 76.31it/s]
# 100%|██████████| 100/100 [00:01<00:00, 74.16it/s]
# 100%|██████████| 100/100 [00:01<00:00, 75.61it/s]
# 100%|██████████| 100/100 [00:01<00:00, 74.24it/s]
# 100%|██████████| 100/100 [00:01<00:00, 74.33it/s]
# 100%|██████████| 100/100 [00:01<00:00, 73.34it/s]
# 100%|██████████| 100/100 [00:01<00:00, 73.57it/s]
# 100%|██████████| 100/100 [00:01<00:00, 75.42it/s]
# 100%|██████████| 100/100 [00:01<00:00, 73.01it/s]
